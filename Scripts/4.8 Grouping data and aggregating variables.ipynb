# %% [markdown]
# ## 4.8 Grouping data and aggregating variables

# %% [markdown]
# ## This script contains the following scripts:
#
# 1. Import libraries and data
#
# 2. Find the aggregated mean of the "number_of_order" column grouped by "department_id" for the subset and the entire dataframe
#
# 3. Analyze the results and differences
#
# 4. Create a loyalty flag using transform() and loc()
#
# 5. Check the basic statistics of the product prices for each loyalty category
#
# 6. Create a spending flag for each user based on the average prices across all their orders
#
# 7. Create an order frequency flag
#
# 8. Ensure the notebook is clean and structured and that the code is well commented
#
# 9. Export the dataframe as a pickle file in Prepared Data folder

# %% [markdown]
# ## 1. Import libraries and data

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# Import data

path = r'C:\Users\admin\06-2024 Instacart Basket Analysis'
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_new_cols.pkl'))

# %% [markdown]
# ## 2. Find the aggregated mean of the "number_of_order" column grouped by "department_id" for the subset and the entire dataframe

# %%
# Create a subset

df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 23)

# %%
df.head(10)
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
# 5             0           1  Chocolate Sandwich Cookies        61
# 6             0           1  Chocolate Sandwich Cookies        61
# 7             0           1  Chocolate Sandwich Cookies        61
# 8             0           1  Chocolate Sandwich Cookies        61
# 9             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0.1  Unnamed: 0_y  order_id  user_id  ...  \
# 0             19     5.8          1987          1987   3139998      138  ...
# 1             19     5.8          1989          1989   1977647      138  ...
# 2             19     5.8         11433         11433    389851      709  ...
# 3             19     5.8         12198         12198    652770      764  ...
# 4             19     5.8         12200         12200   1813452      764  ...
# 5             19     5.8         12372         12372   1701441      777  ...
# 6             19     5.8         13096         13096   1871483      825  ...
# 7             19     5.8         14603         14603   1290456      910  ...
# 8             19     5.8         17065         17065    369558     1052  ...
# 9             19     5.8         17070         17070    589712     1052  ...
#
#   order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# 0                11                     3.0                  5          0
# 1                17                    20.0                  1          1
# 2                21                     6.0                 20          0
# 3                13                    11.0                 10          0
# 4                17                     9.0                 11          1
# 5                 7                    26.0                  7          0
# 6                14                    30.0                  2          0
# 7                10                    30.0                  1          0
# 8                20                    19.0                  1          0
# 9                12                    15.0                  2          1
#
#    _merge  _merge2    price_range_loc   busiest_day  busiest_days  \
# 0    both     both  Mid-range product  Regular busy  Regular busy
# 1    both     both  Mid-range product  Regular busy  Regular busy
# 2    both     both  Mid-range product   Busiest day  Busiest days
# 3    both     both  Mid-range product  Regular busy    Least busy
# 4    both     both  Mid-range product    Least busy    Least busy
# 5    both     both  Mid-range product  Regular busy  Busiest days
# 6    both     both  Mid-range product  Regular busy  Regular busy
# 7    both     both  Mid-range product  Regular busy    Least busy
# 8    both     both  Mid-range product  Regular busy  Busiest days
# 9    both     both  Mid-range product  Regular busy  Busiest days
#
#   busiest_period_of_day_loc
# 0               Most orders
# 1            Average orders
# 2            Average orders
# 3               Most orders
# 4            Average orders
# 5            Average orders
# 6               Most orders
# 7               Most orders
# 8            Average orders
# 9               Most orders
#
# [10 rows x 23 columns]

# %%
# Group data with pandas

df.groupby('product_name')

# %%
# Perform a single aggregation

df.groupby('department_id').agg({'number_of_order': ['mean']})
# Out:
#               number_of_order
#                          mean
# department_id
# 1                   15.577493
# 2                   17.320781
# 3                   16.084944
# 4                   17.530458
# 5                   14.763075
# 6                   16.658449
# 7                   17.031590
# 8                   15.076662
# 9                   15.447580
# 10                  18.681852
# 11                  15.447411
# 12                  14.327957
# 13                  16.548642
# 14                  16.960241
# 15                  16.121948
# 16                  17.803851
# 17                  15.593633
# 18                  19.674252
# 19                  16.899756
# 20                  16.255442
# 21                  25.535479

# %%
df.groupby('department_id')['number_of_order'].mean()
# Out:
# department_id
# 1     15.577493
# 2     17.320781
# 3     16.084944
# 4     17.530458
# 5     14.763075
# 6     16.658449
# 7     17.031590
# 8     15.076662
# 9     15.447580
# 10    18.681852
# 11    15.447411
# 12    14.327957
# 13    16.548642
# 14    16.960241
# 15    16.121948
# 16    17.803851
# 17    15.593633
# 18    19.674252
# 19    16.899756
# 20    16.255442
# 21    25.535479
# Name: number_of_order, dtype: float64

# %%
df.groupby('department_id').number_of_order.mean()
# Out:
# department_id
# 1     15.577493
# 2     17.320781
# 3     16.084944
# 4     17.530458
# 5     14.763075
# 6     16.658449
# 7     17.031590
# 8     15.076662
# 9     15.447580
# 10    18.681852
# 11    15.447411
# 12    14.327957
# 13    16.548642
# 14    16.960241
# 15    16.121948
# 16    17.803851
# 17    15.593633
# 18    19.674252
# 19    16.899756
# 20    16.255442
# 21    25.535479
# Name: number_of_order, dtype: float64

# %%
# Perform multiple aggregations

df.groupby('department_id').agg({'number_of_order': ['mean', 'min', 'max']})
# Out:
#               number_of_order
#                          mean min max
# department_id
# 1                   15.577493   1  99
# 2                   17.320781   1  96
# 3                   16.084944   1  99
# 4                   17.530458   1  99
# 5                   14.763075   1  99
# 6                   16.658449   1  99
# 7                   17.031590   1  99
# 8                   15.076662   1  98
# 9                   15.447580   1  99
# 10                  18.681852   1  99
# 11                  15.447411   1  99
# 12                  14.327957   1  99
# 13                  16.548642   1  99
# 14                  16.960241   1  99
# 15                  16.121948   1  99
# 16                  17.803851   1  99
# 17                  15.593633   1  99
# 18                  19.674252   1  99
# 19                  16.899756   1  99
# 20                  16.255442   1  99
# 21                  25.535479   1  98

# %%
# Find the aggregated mean for the entire dataframe

ords_prods_merge.groupby('department_id')['number_of_order'].mean()
# Out:
# department_id
# 1     15.457838
# 2     17.277920
# 3     17.170395
# 4     17.811403
# 5     15.215751
# 6     16.439806
# 7     17.225802
# 8     15.340650
# 9     15.895474
# 10    20.197148
# 11    16.170638
# 12    15.887671
# 13    16.583536
# 14    16.773669
# 15    16.165037
# 16    17.665606
# 17    15.694469
# 18    19.310397
# 19    17.177343
# 20    16.473447
# 21    22.902379
# Name: number_of_order, dtype: float64

# %% [markdown]
# ## 3. Analyze the results and differences

# %% [markdown]
# Both the entire dataframe and the subset have 'department_id' from 1 to 21. But their means of 'number_of_order' by 'department_id' are different, since the subset only has 1 million rows while the entire dataframe has much more rows.

# %% [markdown]
# ## 4. Create a loyalty flag using transform() and loc()

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['number_of_order'].transform(np.max)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_20688\506111299.py:1: FutureWarning: The provided callable <function max at 0x000002B1B85C2C00> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['number_of_order'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0              0           1  Chocolate Sandwich Cookies        61
# 1              0           1  Chocolate Sandwich Cookies        61
# 2              0           1  Chocolate Sandwich Cookies        61
# 3              0           1  Chocolate Sandwich Cookies        61
# 4              0           1  Chocolate Sandwich Cookies        61
# 5              0           1  Chocolate Sandwich Cookies        61
# 6              0           1  Chocolate Sandwich Cookies        61
# 7              0           1  Chocolate Sandwich Cookies        61
# 8              0           1  Chocolate Sandwich Cookies        61
# 9              0           1  Chocolate Sandwich Cookies        61
# 10             0           1  Chocolate Sandwich Cookies        61
# 11             0           1  Chocolate Sandwich Cookies        61
# 12             0           1  Chocolate Sandwich Cookies        61
# 13             0           1  Chocolate Sandwich Cookies        61
# 14             0           1  Chocolate Sandwich Cookies        61
#
#     department_id  prices  Unnamed: 0.1  Unnamed: 0_y  order_id  user_id  ...  \
# 0              19     5.8          1987          1987   3139998      138  ...
# 1              19     5.8          1989          1989   1977647      138  ...
# 2              19     5.8         11433         11433    389851      709  ...
# 3              19     5.8         12198         12198    652770      764  ...
# 4              19     5.8         12200         12200   1813452      764  ...
# 5              19     5.8         12372         12372   1701441      777  ...
# 6              19     5.8         13096         13096   1871483      825  ...
# 7              19     5.8         14603         14603   1290456      910  ...
# 8              19     5.8         17065         17065    369558     1052  ...
# 9              19     5.8         17070         17070    589712     1052  ...
# 10             19     5.8         22082         22082   1798115     1379  ...
# 11             19     5.8         23713         23713    497193     1480  ...
# 12             19     5.8         23715         23715   1727826     1480  ...
# 13             19     5.8         23716         23716   2694698     1480  ...
# 14             19     5.8         23937         23937   3171753     1494  ...
#
#    days_since_prior_order  add_to_cart_order  reordered  _merge  _merge2  \
# 0                     3.0                  5          0    both     both
# 1                    20.0                  1          1    both     both
# 2                     6.0                 20          0    both     both
# 3                    11.0                 10          0    both     both
# 4                     9.0                 11          1    both     both
# 5                    26.0                  7          0    both     both
# 6                    30.0                  2          0    both     both
# 7                    30.0                  1          0    both     both
# 8                    19.0                  1          0    both     both
# 9                    15.0                  2          1    both     both
# 10                   11.0                  1          0    both     both
# 11                    7.0                  1          0    both     both
# 12                    7.0                  3          1    both     both
# 13                   12.0                  4          1    both     both
# 14                    2.0                  8          0    both     both
#
#       price_range_loc   busiest_day  busiest_days busiest_period_of_day_loc  \
# 0   Mid-range product  Regular busy  Regular busy               Most orders
# 1   Mid-range product  Regular busy  Regular busy            Average orders
# 2   Mid-range product   Busiest day  Busiest days            Average orders
# 3   Mid-range product  Regular busy    Least busy               Most orders
# 4   Mid-range product    Least busy    Least busy            Average orders
# 5   Mid-range product  Regular busy  Busiest days            Average orders
# 6   Mid-range product  Regular busy  Regular busy               Most orders
# 7   Mid-range product  Regular busy    Least busy               Most orders
# 8   Mid-range product  Regular busy  Busiest days            Average orders
# 9   Mid-range product  Regular busy  Busiest days               Most orders
# 10  Mid-range product  Regular busy  Regular busy               Most orders
# 11  Mid-range product  Regular busy    Least busy               Most orders
# 12  Mid-range product    Least busy    Least busy               Most orders
# 13  Mid-range product  Regular busy  Regular busy               Most orders
# 14  Mid-range product  Regular busy    Least busy               Most orders
#
#    max_order
# 0         32
# 1         32
# 2          5
# 3          3
# 4          3
# 5         26
# 6          9
# 7         12
# 8         20
# 9         20
# 10        10
# 11        43
# 12        43
# 13        43
# 14        13
#
# [15 rows x 24 columns]

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0              0           1  Chocolate Sandwich Cookies        61
# 1              0           1  Chocolate Sandwich Cookies        61
# 2              0           1  Chocolate Sandwich Cookies        61
# 3              0           1  Chocolate Sandwich Cookies        61
# 4              0           1  Chocolate Sandwich Cookies        61
# ..           ...         ...                         ...       ...
# 95             0           1  Chocolate Sandwich Cookies        61
# 96             0           1  Chocolate Sandwich Cookies        61
# 97             0           1  Chocolate Sandwich Cookies        61
# 98             0           1  Chocolate Sandwich Cookies        61
# 99             0           1  Chocolate Sandwich Cookies        61
#
#     department_id  prices  Unnamed: 0.1  Unnamed: 0_y  order_id  user_id  ...  \
# 0              19     5.8          1987          1987   3139998      138  ...
# 1              19     5.8          1989          1989   1977647      138  ...
# 2              19     5.8         11433         11433    389851      709  ...
# 3              19     5.8         12198         12198    652770      764  ...
# 4              19     5.8         12200         12200   1813452      764  ...
# ..            ...     ...           ...           ...       ...      ...  ...
# 95             19     5.8        179480        179480    602103    10831  ...
# 96             19     5.8        184011        184011     49629    11119  ...
# 97             19     5.8        185002        185002    317888    11186  ...
# 98             19     5.8        186194        186194    682486    11243  ...
# 99             19     5.8        189258        189258   2861386    11448  ...
#
#    days_since_prior_order  add_to_cart_order  reordered  _merge  _merge2  \
# 0                     3.0                  5          0    both     both
# 1                    20.0                  1          1    both     both
# 2                     6.0                 20          0    both     both
# 3                    11.0                 10          0    both     both
# 4                     9.0                 11          1    both     both
# ..                    ...                ...        ...     ...      ...
# 95                   23.0                  5          0    both     both
# 96                   30.0                  1          0    both     both
# 97                    2.0                  8          0    both     both
# 98                    0.0                  2          0    both     both
# 99                    3.0                  6          0    both     both
#
#       price_range_loc   busiest_day  busiest_days busiest_period_of_day_loc  \
# 0   Mid-range product  Regular busy  Regular busy               Most orders
# 1   Mid-range product  Regular busy  Regular busy            Average orders
# 2   Mid-range product   Busiest day  Busiest days            Average orders
# 3   Mid-range product  Regular busy    Least busy               Most orders
# 4   Mid-range product    Least busy    Least busy            Average orders
# ..                ...           ...           ...                       ...
# 95  Mid-range product  Regular busy    Least busy               Most orders
# 96  Mid-range product  Regular busy  Busiest days               Most orders
# 97  Mid-range product  Regular busy  Regular busy               Most orders
# 98  Mid-range product  Regular busy    Least busy               Most orders
# 99  Mid-range product  Regular busy  Regular busy               Most orders
#
#    max_order
# 0         32
# 1         32
# 2          5
# 3          3
# 4          3
# ..       ...
# 95        10
# 96        23
# 97        26
# 98        43
# 99        21
#
# [100 rows x 24 columns]

# %%
# Tell panda not to assign any options regarding the max number of rows to display

pd.options.display.max_rows = None

# %%
ords_prods_merge.head(50)
# Out:
#     Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0              0           1  Chocolate Sandwich Cookies        61
# 1              0           1  Chocolate Sandwich Cookies        61
# 2              0           1  Chocolate Sandwich Cookies        61
# 3              0           1  Chocolate Sandwich Cookies        61
# 4              0           1  Chocolate Sandwich Cookies        61
# 5              0           1  Chocolate Sandwich Cookies        61
# 6              0           1  Chocolate Sandwich Cookies        61
# 7              0           1  Chocolate Sandwich Cookies        61
# 8              0           1  Chocolate Sandwich Cookies        61
# 9              0           1  Chocolate Sandwich Cookies        61
# 10             0           1  Chocolate Sandwich Cookies        61
# 11             0           1  Chocolate Sandwich Cookies        61
# 12             0           1  Chocolate Sandwich Cookies        61
# 13             0           1  Chocolate Sandwich Cookies        61
# 14             0           1  Chocolate Sandwich Cookies        61
# 15             0           1  Chocolate Sandwich Cookies        61
# 16             0           1  Chocolate Sandwich Cookies        61
# 17             0           1  Chocolate Sandwich Cookies        61
# 18             0           1  Chocolate Sandwich Cookies        61
# 19             0           1  Chocolate Sandwich Cookies        61
# 20             0           1  Chocolate Sandwich Cookies        61
# 21             0           1  Chocolate Sandwich Cookies        61
# 22             0           1  Chocolate Sandwich Cookies        61
# 23             0           1  Chocolate Sandwich Cookies        61
# 24             0           1  Chocolate Sandwich Cookies        61
# 25             0           1  Chocolate Sandwich Cookies        61
# 26             0           1  Chocolate Sandwich Cookies        61
# 27             0           1  Chocolate Sandwich Cookies        61
# 28             0           1  Chocolate Sandwich Cookies        61
# 29             0           1  Chocolate Sandwich Cookies        61
# 30             0           1  Chocolate Sandwich Cookies        61
# 31             0           1  Chocolate Sandwich Cookies        61
# 32             0           1  Chocolate Sandwich Cookies        61
# 33             0           1  Chocolate Sandwich Cookies        61
# 34             0           1  Chocolate Sandwich Cookies        61
# 35             0           1  Chocolate Sandwich Cookies        61
# 36             0           1  Chocolate Sandwich Cookies        61
# 37             0           1  Chocolate Sandwich Cookies        61
# 38             0           1  Chocolate Sandwich Cookies        61
# 39             0           1  Chocolate Sandwich Cookies        61
# 40             0           1  Chocolate Sandwich Cookies        61
# 41             0           1  Chocolate Sandwich Cookies        61
# 42             0           1  Chocolate Sandwich Cookies        61
# 43             0           1  Chocolate Sandwich Cookies        61
# 44             0           1  Chocolate Sandwich Cookies        61
# 45             0           1  Chocolate Sandwich Cookies        61
# 46             0           1  Chocolate Sandwich Cookies        61
# 47             0           1  Chocolate Sandwich Cookies        61
# 48             0           1  Chocolate Sandwich Cookies        61
# 49             0           1  Chocolate Sandwich Cookies        61
#
#     department_id  prices  Unnamed: 0.1  Unnamed: 0_y  order_id  user_id  ...  \
# 0              19     5.8          1987          1987   3139998      138  ...
# 1              19     5.8          1989          1989   1977647      138  ...
# 2              19     5.8         11433         11433    389851      709  ...
# 3              19     5.8         12198         12198    652770      764  ...
# 4              19     5.8         12200         12200   1813452      764  ...
# 5              19     5.8         12372         12372   1701441      777  ...
# 6              19     5.8         13096         13096   1871483      825  ...
# 7              19     5.8         14603         14603   1290456      910  ...
# 8              19     5.8         17065         17065    369558     1052  ...
# 9              19     5.8         17070         17070    589712     1052  ...
# 10             19     5.8         22082         22082   1798115     1379  ...
# 11             19     5.8         23713         23713    497193     1480  ...
# 12             19     5.8         23715         23715   1727826     1480  ...
# 13             19     5.8         23716         23716   2694698     1480  ...
# 14             19     5.8         23937         23937   3171753     1494  ...
# 15             19     5.8         23938         23938    186761     1494  ...
# 16             19     5.8         23940         23940    317121     1494  ...
# 17             19     5.8         24740         24740    200390     1540  ...
# 18             19     5.8         24741         24741    374436     1540  ...
# 19             19     5.8         24742         24742   2920553     1540  ...
# 20             19     5.8         24743         24743   2813049     1540  ...
# 21             19     5.8         24744         24744   2365998     1540  ...
# 22             19     5.8         24745         24745   1604797     1540  ...
# 23             19     5.8         24750         24750   2799665     1540  ...
# 24             19     5.8         24751         24751   2228851     1540  ...
# 25             19     5.8         24754         24754   2337422     1540  ...
# 26             19     5.8         24755         24755   2699008     1540  ...
# 27             19     5.8         24756         24756   1914830     1540  ...
# 28             19     5.8         24757         24757    783503     1540  ...
# 29             19     5.8         24758         24758   2500516     1540  ...
# 30             19     5.8         24760         24760    716845     1540  ...
# 31             19     5.8         24761         24761   1955535     1540  ...
# 32             19     5.8         24763         24763   1424793     1540  ...
# 33             19     5.8         24764         24764    749498     1540  ...
# 34             19     5.8         25854         25854   2434812     1598  ...
# 35             19     5.8         25855         25855   1531889     1598  ...
# 36             19     5.8         25856         25856    726947     1598  ...
# 37             19     5.8         26514         26514    627615     1647  ...
# 38             19     5.8         26517         26517   2507439     1647  ...
# 39             19     5.8         26519         26519   1152609     1647  ...
# 40             19     5.8         26521         26521   1048339     1647  ...
# 41             19     5.8         26522         26522   2818381     1647  ...
# 42             19     5.8         45857         45857   2722928     2833  ...
# 43             19     5.8         46112         46112   1482338     2850  ...
# 44             19     5.8         46221         46221   2311344     2857  ...
# 45             19     5.8         48737         48737    812943     3010  ...
# 46             19     5.8         49060         49060    256839     3029  ...
# 47             19     5.8         54482         54482   2192488     3395  ...
# 48             19     5.8         63154         63154    207661     3904  ...
# 49             19     5.8         64629         64629   1394659     4006  ...
#
#    days_since_prior_order  add_to_cart_order  reordered  _merge  _merge2  \
# 0                     3.0                  5          0    both     both
# 1                    20.0                  1          1    both     both
# 2                     6.0                 20          0    both     both
# 3                    11.0                 10          0    both     both
# 4                     9.0                 11          1    both     both
# 5                    26.0                  7          0    both     both
# 6                    30.0                  2          0    both     both
# 7                    30.0                  1          0    both     both
# 8                    19.0                  1          0    both     both
# 9                    15.0                  2          1    both     both
# 10                   11.0                  1          0    both     both
# 11                    7.0                  1          0    both     both
# 12                    7.0                  3          1    both     both
# 13                   12.0                  4          1    both     both
# 14                    2.0                  8          0    both     both
# 15                    6.0                 18          1    both     both
# 16                   10.0                 12          1    both     both
# 17                    7.0                 10          0    both     both
# 18                    6.0                  9          1    both     both
# 19                   14.0                  9          1    both     both
# 20                    8.0                  7          1    both     both
# 21                    6.0                  6          1    both     both
# 22                   28.0                  6          1    both     both
# 23                    7.0                 10          1    both     both
# 24                    7.0                  3          1    both     both
# 25                    0.0                  5          1    both     both
# 26                    7.0                 11          1    both     both
# 27                    7.0                 11          1    both     both
# 28                    7.0                  5          1    both     both
# 29                    7.0                 15          1    both     both
# 30                    3.0                  4          1    both     both
# 31                   16.0                  6          1    both     both
# 32                    5.0                  1          1    both     both
# 33                    6.0                  1          1    both     both
# 34                   11.0                  2          0    both     both
# 35                   21.0                  2          1    both     both
# 36                    2.0                  3          1    both     both
# 37                   11.0                  1          0    both     both
# 38                   18.0                  6          1    both     both
# 39                    8.0                  3          1    both     both
# 40                   30.0                 10          1    both     both
# 41                   25.0                  1          1    both     both
# 42                   11.0                 12          0    both     both
# 43                    9.0                 10          0    both     both
# 44                   10.0                  5          0    both     both
# 45                    7.0                 11          0    both     both
# 46                   11.0                  8          0    both     both
# 47                   30.0                  7          0    both     both
# 48                   11.0                  2          0    both     both
# 49                    7.0                  8          0    both     both
#
#       price_range_loc   busiest_day  busiest_days busiest_period_of_day_loc  \
# 0   Mid-range product  Regular busy  Regular busy               Most orders
# 1   Mid-range product  Regular busy  Regular busy            Average orders
# 2   Mid-range product   Busiest day  Busiest days            Average orders
# 3   Mid-range product  Regular busy    Least busy               Most orders
# 4   Mid-range product    Least busy    Least busy            Average orders
# 5   Mid-range product  Regular busy  Busiest days            Average orders
# 6   Mid-range product  Regular busy  Regular busy               Most orders
# 7   Mid-range product  Regular busy    Least busy               Most orders
# 8   Mid-range product  Regular busy  Busiest days            Average orders
# 9   Mid-range product  Regular busy  Busiest days               Most orders
# 10  Mid-range product  Regular busy  Regular busy               Most orders
# 11  Mid-range product  Regular busy    Least busy               Most orders
# 12  Mid-range product    Least busy    Least busy               Most orders
# 13  Mid-range product  Regular busy  Regular busy               Most orders
# 14  Mid-range product  Regular busy    Least busy               Most orders
# 15  Mid-range product  Regular busy  Regular busy            Average orders
# 16  Mid-range product  Regular busy  Regular busy            Average orders
# 17  Mid-range product  Regular busy  Regular busy              Fewer orders
# 18  Mid-range product  Regular busy  Busiest days            Average orders
# 19  Mid-range product  Regular busy  Busiest days              Fewer orders
# 20  Mid-range product  Regular busy  Regular busy              Fewer orders
# 21  Mid-range product  Regular busy  Busiest days              Fewer orders
# 22  Mid-range product  Regular busy  Busiest days              Fewer orders
# 23  Mid-range product  Regular busy  Busiest days               Most orders
# 24  Mid-range product  Regular busy  Busiest days               Most orders
# 25  Mid-range product   Busiest day  Busiest days            Average orders
# 26  Mid-range product   Busiest day  Busiest days            Average orders
# 27  Mid-range product   Busiest day  Busiest days            Average orders
# 28  Mid-range product   Busiest day  Busiest days            Average orders
# 29  Mid-range product   Busiest day  Busiest days            Average orders
# 30  Mid-range product    Least busy    Least busy            Average orders
# 31  Mid-range product  Regular busy  Regular busy            Average orders
# 32  Mid-range product  Regular busy  Busiest days              Fewer orders
# 33  Mid-range product   Busiest day  Busiest days            Average orders
# 34  Mid-range product  Regular busy  Regular busy               Most orders
# 35  Mid-range product  Regular busy  Regular busy               Most orders
# 36  Mid-range product    Least busy    Least busy            Average orders
# 37  Mid-range product  Regular busy  Busiest days               Most orders
# 38  Mid-range product   Busiest day  Busiest days               Most orders
# 39  Mid-range product  Regular busy  Busiest days               Most orders
# 40  Mid-range product   Busiest day  Busiest days            Average orders
# 41  Mid-range product    Least busy    Least busy               Most orders
# 42  Mid-range product   Busiest day  Busiest days               Most orders
# 43  Mid-range product  Regular busy  Busiest days               Most orders
# 44  Mid-range product  Regular busy  Busiest days            Average orders
# 45  Mid-range product  Regular busy    Least busy               Most orders
# 46  Mid-range product  Regular busy  Regular busy            Average orders
# 47  Mid-range product  Regular busy  Regular busy               Most orders
# 48  Mid-range product  Regular busy  Busiest days               Most orders
# 49  Mid-range product  Regular busy  Busiest days               Most orders
#
#    max_order
# 0         32
# 1         32
# 2          5
# 3          3
# 4          3
# 5         26
# 6          9
# 7         12
# 8         20
# 9         20
# 10        10
# 11        43
# 12        43
# 13        43
# 14        13
# 15        13
# 16        13
# 17        28
# 18        28
# 19        28
# 20        28
# 21        28
# 22        28
# 23        28
# 24        28
# 25        28
# 26        28
# 27        28
# 28        28
# 29        28
# 30        28
# 31        28
# 32        28
# 33        28
# 34         4
# 35         4
# 36         4
# 37        10
# 38        10
# 39        10
# 40        10
# 41        10
# 42        10
# 43        23
# 44        25
# 45        13
# 46         5
# 47         6
# 48         3
# 49        42
#
# [50 rows x 24 columns]

# %%
# Deriving columns with loc()

ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'number_of_order']].head(60)
# Out:
#     user_id      loyalty_flag  number_of_order
# 0       138  Regular customer               28
# 1       138  Regular customer               30
# 2       709      New customer                2
# 3       764      New customer                1
# 4       764      New customer                3
# 5       777  Regular customer               16
# 6       825      New customer                3
# 7       910  Regular customer               12
# 8      1052  Regular customer               10
# 9      1052  Regular customer               15
# 10     1379      New customer                1
# 11     1480    Loyal customer               36
# 12     1480    Loyal customer               38
# 13     1480    Loyal customer               39
# 14     1494  Regular customer                6
# 15     1494  Regular customer                7
# 16     1494  Regular customer                9
# 17     1540  Regular customer                4
# 18     1540  Regular customer                5
# 19     1540  Regular customer                6
# 20     1540  Regular customer                7
# 21     1540  Regular customer                8
# 22     1540  Regular customer                9
# 23     1540  Regular customer               14
# 24     1540  Regular customer               15
# 25     1540  Regular customer               18
# 26     1540  Regular customer               19
# 27     1540  Regular customer               20
# 28     1540  Regular customer               21
# 29     1540  Regular customer               22
# 30     1540  Regular customer               24
# 31     1540  Regular customer               25
# 32     1540  Regular customer               27
# 33     1540  Regular customer               28
# 34     1598      New customer                1
# 35     1598      New customer                2
# 36     1598      New customer                3
# 37     1647      New customer                1
# 38     1647      New customer                4
# 39     1647      New customer                6
# 40     1647      New customer                8
# 41     1647      New customer                9
# 42     2833      New customer                1
# 43     2850  Regular customer                7
# 44     2857  Regular customer               24
# 45     3010  Regular customer                5
# 46     3029      New customer                1
# 47     3395      New customer                4
# 48     3904      New customer                1
# 49     4006    Loyal customer                2
# 50     4006    Loyal customer                3
# 51     4006    Loyal customer                5
# 52     4006    Loyal customer                9
# 53     4006    Loyal customer               12
# 54     4122  Regular customer               11
# 55     4141      New customer                2
# 56     4343      New customer                1
# 57     4553      New customer                3
# 58     4845  Regular customer                6
# 59     6866      New customer                1

# %% [markdown]
# ## 5. Check the basic statistics of the product prices for each loyalty category

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# The mean of product prices for Loyal customer (10.37) is a little lower than the means of product prices for Regular customer (13.29) and New customer (12.5).

# %% [markdown]
# ## 6. Create a spending flag for each user based on the average prices across all their orders

# %%
ords_prods_merge['average_prices'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_20688\1640056616.py:1: FutureWarning: The provided callable <function mean at 0x000002B1B85C3600> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['average_prices'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0              0           1  Chocolate Sandwich Cookies        61
# 1              0           1  Chocolate Sandwich Cookies        61
# 2              0           1  Chocolate Sandwich Cookies        61
# 3              0           1  Chocolate Sandwich Cookies        61
# 4              0           1  Chocolate Sandwich Cookies        61
# 5              0           1  Chocolate Sandwich Cookies        61
# 6              0           1  Chocolate Sandwich Cookies        61
# 7              0           1  Chocolate Sandwich Cookies        61
# 8              0           1  Chocolate Sandwich Cookies        61
# 9              0           1  Chocolate Sandwich Cookies        61
# 10             0           1  Chocolate Sandwich Cookies        61
# 11             0           1  Chocolate Sandwich Cookies        61
# 12             0           1  Chocolate Sandwich Cookies        61
# 13             0           1  Chocolate Sandwich Cookies        61
# 14             0           1  Chocolate Sandwich Cookies        61
#
#     department_id  prices  Unnamed: 0.1  Unnamed: 0_y  order_id  user_id  ...  \
# 0              19     5.8          1987          1987   3139998      138  ...
# 1              19     5.8          1989          1989   1977647      138  ...
# 2              19     5.8         11433         11433    389851      709  ...
# 3              19     5.8         12198         12198    652770      764  ...
# 4              19     5.8         12200         12200   1813452      764  ...
# 5              19     5.8         12372         12372   1701441      777  ...
# 6              19     5.8         13096         13096   1871483      825  ...
# 7              19     5.8         14603         14603   1290456      910  ...
# 8              19     5.8         17065         17065    369558     1052  ...
# 9              19     5.8         17070         17070    589712     1052  ...
# 10             19     5.8         22082         22082   1798115     1379  ...
# 11             19     5.8         23713         23713    497193     1480  ...
# 12             19     5.8         23715         23715   1727826     1480  ...
# 13             19     5.8         23716         23716   2694698     1480  ...
# 14             19     5.8         23937         23937   3171753     1494  ...
#
#    reordered  _merge  _merge2    price_range_loc   busiest_day  busiest_days  \
# 0          0    both     both  Mid-range product  Regular busy  Regular busy
# 1          1    both     both  Mid-range product  Regular busy  Regular busy
# 2          0    both     both  Mid-range product   Busiest day  Busiest days
# 3          0    both     both  Mid-range product  Regular busy    Least busy
# 4          1    both     both  Mid-range product    Least busy    Least busy
# 5          0    both     both  Mid-range product  Regular busy  Busiest days
# 6          0    both     both  Mid-range product  Regular busy  Regular busy
# 7          0    both     both  Mid-range product  Regular busy    Least busy
# 8          0    both     both  Mid-range product  Regular busy  Busiest days
# 9          1    both     both  Mid-range product  Regular busy  Busiest days
# 10         0    both     both  Mid-range product  Regular busy  Regular busy
# 11         0    both     both  Mid-range product  Regular busy    Least busy
# 12         1    both     both  Mid-range product    Least busy    Least busy
# 13         1    both     both  Mid-range product  Regular busy  Regular busy
# 14         0    both     both  Mid-range product  Regular busy    Least busy
#
#     busiest_period_of_day_loc max_order      loyalty_flag average_prices
# 0                 Most orders        32  Regular customer       6.935811
# 1              Average orders        32  Regular customer       6.935811
# 2              Average orders         5      New customer       7.930208
# 3                 Most orders         3      New customer       4.972414
# 4              Average orders         3      New customer       4.972414
# 5              Average orders        26  Regular customer       6.935398
# 6                 Most orders         9      New customer       5.957576
# 7                 Most orders        12  Regular customer       6.680000
# 8              Average orders        20  Regular customer       7.162500
# 9                 Most orders        20  Regular customer       7.162500
# 10                Most orders        10      New customer       5.813636
# 11                Most orders        43    Loyal customer       5.081633
# 12                Most orders        43    Loyal customer       5.081633
# 13                Most orders        43    Loyal customer       5.081633
# 14                Most orders        13  Regular customer       6.803797
#
# [15 rows x 26 columns]

# %%
# Create a spending flag for each user

ords_prods_merge.loc[ords_prods_merge['average_prices'] < 10, 'spending_flag'] = 'Low spender'
ords_prods_merge.loc[ords_prods_merge['average_prices'] >= 10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     31770614
# High spender      634245
# Name: count, dtype: int64

# %% [markdown]
# ## 7. Create an order frequency flag

# %%
ords_prods_merge['median_days_since_prior_order'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_20688\2588299015.py:1: FutureWarning: The provided callable <function median at 0x000002B1B873ADE0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   ords_prods_merge['median_days_since_prior_order'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0.1  Unnamed: 0_y  order_id  user_id  ...  \
# 0             19     5.8          1987          1987   3139998      138  ...
# 1             19     5.8          1989          1989   1977647      138  ...
# 2             19     5.8         11433         11433    389851      709  ...
# 3             19     5.8         12198         12198    652770      764  ...
# 4             19     5.8         12200         12200   1813452      764  ...
#
#   _merge2    price_range_loc   busiest_day  busiest_days  \
# 0    both  Mid-range product  Regular busy  Regular busy
# 1    both  Mid-range product  Regular busy  Regular busy
# 2    both  Mid-range product   Busiest day  Busiest days
# 3    both  Mid-range product  Regular busy    Least busy
# 4    both  Mid-range product    Least busy    Least busy
#
#    busiest_period_of_day_loc  max_order      loyalty_flag average_prices  \
# 0                Most orders         32  Regular customer       6.935811
# 1             Average orders         32  Regular customer       6.935811
# 2             Average orders          5      New customer       7.930208
# 3                Most orders          3      New customer       4.972414
# 4             Average orders          3      New customer       4.972414
#
#   spending_flag median_days_since_prior_order
# 0   Low spender                           8.0
# 1   Low spender                           8.0
# 2   Low spender                           8.0
# 3   Low spender                          11.0
# 4   Low spender                          11.0
#
# [5 rows x 28 columns]

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'
ords_prods_merge.loc[(ords_prods_merge['median_days_since_prior_order'] > 10) & (ords_prods_merge['median_days_since_prior_order'] <= 20), 'order_frequency_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0.1  Unnamed: 0_y  order_id  user_id  ...  \
# 0             19     5.8          1987          1987   3139998      138  ...
# 1             19     5.8          1989          1989   1977647      138  ...
# 2             19     5.8         11433         11433    389851      709  ...
# 3             19     5.8         12198         12198    652770      764  ...
# 4             19     5.8         12200         12200   1813452      764  ...
#
#      price_range_loc   busiest_day  busiest_days  busiest_period_of_day_loc  \
# 0  Mid-range product  Regular busy  Regular busy                Most orders
# 1  Mid-range product  Regular busy  Regular busy             Average orders
# 2  Mid-range product   Busiest day  Busiest days             Average orders
# 3  Mid-range product  Regular busy    Least busy                Most orders
# 4  Mid-range product    Least busy    Least busy             Average orders
#
#    max_order      loyalty_flag  average_prices spending_flag  \
# 0         32  Regular customer        6.935811   Low spender
# 1         32  Regular customer        6.935811   Low spender
# 2          5      New customer        7.930208   Low spender
# 3          3      New customer        4.972414   Low spender
# 4          3      New customer        4.972414   Low spender
#
#   median_days_since_prior_order order_frequency_flag
# 0                           8.0    Frequent customer
# 1                           8.0    Frequent customer
# 2                           8.0    Frequent customer
# 3                          11.0     Regular customer
# 4                          11.0     Regular customer
#
# [5 rows x 29 columns]

# %% [markdown]
# ## 8. Ensure the notebook is clean and structured and that the code is well commented

# %% [markdown]
# ## 9. Export the dataframe as a pickle file in Prepared Data folder

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_new_cols_grouped.pkl'))
